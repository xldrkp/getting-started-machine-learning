# %% [markdown]
# # Experimente mit matplotlib

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

plt.plot([0, 2, 3, 4])
plt.ylabel('some numbers')
plt.xlabel('some other numbers')
plt.show()
